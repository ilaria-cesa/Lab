# %%
import pandas as pd #va messo solo una volta
pd.set_option('display.max_colwidth', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_excel(r"C:\Users\PC\Documents\3 anno\Lab_sistemi_informativi\Lab\Data\Raw\earth_day_tweets_sentiment_50k_(2).xlsx")
df
# Out:
#                                                                                                                                                                                                                                                                                                                                        text  \
# 0                                                                                                                                                                                                        RT @Amyk_Essentials: Happy Earth Day 🌎\nTreat yourself to something that celebrates the beauty of nature 🍃 https://t.co/sQUpM2iLUn
# 1                                                                                                                                                                                                                                                                        RT @WUTangKids: Make Earth Day Every Day!  https://t.co/ymjGmexsjo
# 2                                                                                                                                                                                                                                                                           Earth Day, every day. \n#EarthDay2022 🌍 https://t.co/hz7WiZ6zkO
# 3      RT @wbcsd: On #EarthDay, @wbcsd proudly announces frontrunner companies that are leading the way to eliminating wastewater pollution &amp; improving water quality.\nH&amp;M Group, @UPLLtd and @Chevron are engaging in our wastewater zero initiative to improve water quality. \n👉https://t.co/sbr2VbBK8a https://t.co/wMXrXQ0HXn
# 4                                                                                                                                                                                                    RT @lihosny: I’m fighting for a greener, healthier, affordable and more caring Ontario this #EarthDay. It’s time to #MakeOntarioGreen!
# ...                                                                                                                                                                                                                                                                                                                                     ...
# 50095                                                       Did you know? The Canadian Coalition on Acid Rain (1981–91) helped obtain agreements between Canada and the United States to reduce sulphur dioxide and nitrogen oxide emissions. Learn more about the environmental movement in Canada this #EarthDay: https://t.co/AfZbDZTmdO
# 50096                                                                                                                                                                                                                Today, EERE celebrates #EarthDay by making several announcements and that #InvestInOurPlanet and support clean energy.
# 50097                                                                                                                                                                                                          RT @latestinspace: Happy Earth Day! These images were taken by NASA's goes-16 satellite this morning https://t.co/GsdQO5YlpP
# 50098                                                                                                                                                                                                                                                                     Happy earth day I work between two construction sites it’s FILTHY
# 50099                                                                                                                                                                                                                                                                             RT @maxinevee: Happy Earth Day 🌳💚 https://t.co/Kr6vEIWXdc
#
#                         hash_tags                account_tags sentiment  \
# 0                             NaN             Amyk_Essentials  POSITIVE
# 1                             NaN                  WUTangKids  NEGATIVE
# 2                    EarthDay2022                         NaN  NEGATIVE
# 3                        EarthDay  wbcsd,wbcsd,UPLLtd,Chevron  POSITIVE
# 4       EarthDay,MakeOntarioGreen                     lihosny  POSITIVE
# ...                           ...                         ...       ...
# 50095                    EarthDay                         NaN  NEGATIVE
# 50096  EarthDay,InvestInOurPlanet                         NaN  POSITIVE
# 50097                         NaN               latestinspace  POSITIVE
# 50098                         NaN                         NaN  NEGATIVE
# 50099                         NaN                   maxinevee  POSITIVE
#
#         emotion
# 0           joy
# 1           joy
# 2           joy
# 3      optimism
# 4      optimism
# ...         ...
# 50095  optimism
# 50096  optimism
# 50097       joy
# 50098   sadness
# 50099       joy
#
# [50100 rows x 5 columns]

# %%
df.shape
# Out:
# (50100, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50100 entries, 0 to 50099
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text          50100 non-null  object
#  1   hash_tags     29331 non-null  object
#  2   account_tags  38679 non-null  object
#  3   sentiment     50100 non-null  object
#  4   emotion       50100 non-null  object
# dtypes: object(5)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#                                                                                                                                                                                                                                                             text  \
# count                                                                                                                                                                                                                                                      50100
# unique                                                                                                                                                                                                                                                     26185
# top     RT @BarackObama: When it comes to climate change, time really is running out. Earth Day is a reminder that if we pledge to do our part and then follow through on those commitments, we can help preserve and protect our planet for future generations.
# freq                                                                                                                                                                                                                                                         655
#
#        hash_tags account_tags sentiment emotion
# count      29331        38679     50100   50100
# unique      8233        13209         2       4
# top     EarthDay   cpsavesoil  POSITIVE     joy
# freq        9680         1224     32854   29031

# %%
#n di duplicates
duplicate = df.duplicated().sum()
print(duplicate)
# Out:
# 23915

# %%
df_nodup = df.drop_duplicates()
print(df_nodup.shape)
# Out:
# (26185, 5)

# %%
#% di missing
missing_values = df_nodup.isnull().sum()/len(df_nodup)
print(missing_values)
# Out:
# text            0.000000
# hash_tags       0.363758
# account_tags    0.432500
# sentiment       0.000000
# emotion         0.000000
# dtype: float64

# %%
df_nodup["emotion"].value_counts(normalize=True)
# Out:
# emotion
# joy         0.590262
# optimism    0.343365
# anger       0.035135
# sadness     0.031239
# Name: proportion, dtype: float64

# %%
# BALANCE
print(df_nodup['sentiment'].value_counts(normalize=True))
# Out:
# sentiment
# POSITIVE    0.704564
# NEGATIVE    0.295436
# Name: proportion, dtype: float64

# %%
#pulisco
df_nodup['text'] = df_nodup['text'].str.lower()
df_nodup
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9996\1027348856.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nodup['text'] = df_nodup['text'].str.lower()
#                                                                                                                                                                                                                                                                                          text  \
# 0                                                                                                                                                                                 rt @amyk_essentials: happy earth day 🌎\ntreat yourself to something that celebrates the beauty of nature 🍃
# 1                                                                                                                                                                                                                                                 rt @wutangkids: make earth day every day!
# 2                                                                                                                                                                                                                                                    earth day, every day. \n#earthday2022 🌍
# 3      rt @wbcsd: on #earthday, @wbcsd proudly announces frontrunner companies that are leading the way to eliminating wastewater pollution &amp; improving water quality.\nh&amp;m group, @uplltd and @chevron are engaging in our wastewater zero initiative to improve water quality. \n👉
# 4                                                                                                                                                      rt @lihosny: i’m fighting for a greener, healthier, affordable and more caring ontario this #earthday. it’s time to #makeontariogreen!
# ...                                                                                                                                                                                                                                                                                       ...
# 50091                                         keep the #earthday fun revolving with another earth day re-read this time from our very own agronomy manager jennifer jones telling us "what to do when the water doesn’t turn off – managing cover crops in a wet spring"\n\nread it now at:
# 50092                                                                                           rt @earthjustice: many of the habitats that species/animals depend on are at risk of habitat destruction, which is why we’re using our legal expertise to keep ecosystems intact. #earthday
# 50095                                did you know? the canadian coalition on acid rain (1981–91) helped obtain agreements between canada and the united states to reduce sulphur dioxide and nitrogen oxide emissions. learn more about the environmental movement in canada this #earthday:
# 50096                                                                                                                                                                  today, eere celebrates #earthday by making several announcements and that #investinourplanet and support clean energy.
# 50098                                                                                                                                                                                                                       happy earth day i work between two construction sites it’s filthy
#
#                         hash_tags                account_tags sentiment  \
# 0                             NaN             Amyk_Essentials  POSITIVE
# 1                             NaN                  WUTangKids  NEGATIVE
# 2                    EarthDay2022                         NaN  NEGATIVE
# 3                        EarthDay  wbcsd,wbcsd,UPLLtd,Chevron  POSITIVE
# 4       EarthDay,MakeOntarioGreen                     lihosny  POSITIVE
# ...                           ...                         ...       ...
# 50091                    EarthDay                         NaN  NEGATIVE
# 50092                    EarthDay                Earthjustice  NEGATIVE
# 50095                    EarthDay                         NaN  NEGATIVE
# 50096  EarthDay,InvestInOurPlanet                         NaN  POSITIVE
# 50098                         NaN                         NaN  NEGATIVE
#
#         emotion
# 0           joy
# 1           joy
# 2           joy
# 3      optimism
# 4      optimism
# ...         ...
# 50091       joy
# 50092  optimism
# 50095  optimism
# 50096  optimism
# 50098   sadness
#
# [26185 rows x 5 columns]

# %%
# elimino i link
df_nodup['text'] = df_nodup['text'].apply(lambda x: re.sub(r'http[s]?://\S+|www\.\S+|\S+\.(com|org|net|gov|edu)\S*', '', str(x)))
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9996\3859108683.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nodup['text'] = df_nodup['text'].apply(lambda x: re.sub(r'http[s]?://\S+|www\.\S+|\S+\.(com|org|net|gov|edu)\S*', '', str(x)))

# %%
# elimino gli # e @ e RT
df_nodup['text'] = df_nodup['text'].apply(lambda x: re.sub(r'(?i)\bRT\b|[#@]\S+', '', str(x)))
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9996\2312952624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nodup['text'] = df_nodup['text'].apply(lambda x: re.sub(r'(?i)\bRT\b|[#@]\S+', '', str(x)))

# %%
#rimuovo punteggiatura e simboli
import string
df_nodup['text'] = df_nodup['text'].str.replace(f"[{string.punctuation}]", "", regex=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9996\2012446597.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nodup['text'] = df_nodup['text'].str.replace(f"[{string.punctuation}]", "", regex=True)

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

df_nodup['text'] = df_nodup['text'].apply(remove_stopwords)

df_nodup
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\PC\AppData\Local\Temp\ipykernel_9996\2284734964.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nodup['text'] = df_nodup['text'].apply(remove_stopwords)
#                                                                                                                                                                                            text  \
# 0                                                                                                                                  happy earth day 🌎 treat something celebrates beauty nature 🍃
# 1                                                                                                                                                                      make earth day every day
# 2                                                                                                                                                                         earth day every day 🌍
# 3      proudly announces frontrunner companies leading way eliminating wastewater pollution amp improving water quality hampm group engaging wastewater zero initiative improve water quality 👉
# 4                                                                                                                            i’m fighting greener healthier affordable caring ontario it’s time
# ...                                                                                                                                                                                         ...
# 50091                                     keep fun revolving another earth day reread time agronomy manager jennifer jones telling us water doesn’t turn – managing cover crops wet spring read
# 50092                                                                           many habitats speciesanimals depend risk habitat destruction we’re using legal expertise keep ecosystems intact
# 50095               know canadian coalition acid rain 1981–91 helped obtain agreements canada united states reduce sulphur dioxide nitrogen oxide emissions learn environmental movement canada
# 50096                                                                                                                   today eere celebrates making several announcements support clean energy
# 50098                                                                                                                                   happy earth day work two construction sites it’s filthy
#
#                         hash_tags                account_tags sentiment  \
# 0                             NaN             Amyk_Essentials  POSITIVE
# 1                             NaN                  WUTangKids  NEGATIVE
# 2                    EarthDay2022                         NaN  NEGATIVE
# 3                        EarthDay  wbcsd,wbcsd,UPLLtd,Chevron  POSITIVE
# 4       EarthDay,MakeOntarioGreen                     lihosny  POSITIVE
# ...                           ...                         ...       ...
# 50091                    EarthDay                         NaN  NEGATIVE
# 50092                    EarthDay                Earthjustice  NEGATIVE
# 50095                    EarthDay                         NaN  NEGATIVE
# 50096  EarthDay,InvestInOurPlanet                         NaN  POSITIVE
# 50098                         NaN                         NaN  NEGATIVE
#
#         emotion
# 0           joy
# 1           joy
# 2           joy
# 3      optimism
# 4      optimism
# ...         ...
# 50091       joy
# 50092  optimism
# 50095  optimism
# 50096  optimism
# 50098   sadness
#
# [26185 rows x 5 columns]
